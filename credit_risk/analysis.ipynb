# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('credit_risk_dataset.csv')
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df.head()
# Out:
#    person_age  person_income person_home_ownership  person_emp_length  \
# 0          22          59000                  RENT              123.0
# 1          21           9600                   OWN                5.0
# 2          25           9600              MORTGAGE                1.0
# 3          23          65500                  RENT                4.0
# 4          24          54400                  RENT                8.0
#
#   loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0    PERSONAL          D      35000          16.02            1
# 1   EDUCATION          B       1000          11.14            0
# 2     MEDICAL          C       5500          12.87            1
# 3     MEDICAL          C      35000          15.23            1
# 4     MEDICAL          C      35000          14.27            1
#
#    loan_percent_income cb_person_default_on_file  cb_person_cred_hist_length
# 0                 0.59                         Y                           3
# ...

# %%
df.tail()
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32576         PERSONAL          C       5800          13.16            0
# 32577         PERSONAL          A      17625           7.49            0
# 32578  HOMEIMPROVEMENT          B      35000          10.99            1
# 32579         PERSONAL          B      15000          11.48            0
# 32580          MEDICAL          B       6475           9.99            0
#
#        loan_percent_income cb_person_default_on_file  \
# ...

# %%
df.sample(5)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 4725           23          28800                  RENT                2.0
# 17210          26         127992              MORTGAGE               10.0
# 25613          29          90000                  RENT                4.0
# 32011          36          25000              MORTGAGE                0.0
# 6935           22          50400              MORTGAGE                0.0
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 4725      VENTURE          C       5000          13.11            0
# 17210    PERSONAL          C      26000          13.99            0
# 25613     VENTURE          B      12000          10.74            0
# 32011     MEDICAL          B       3000           8.70            0
# 6935      VENTURE          A      12000           7.90            0
#
#        loan_percent_income cb_person_default_on_file  \
# 4725                  0.17                         N
# ...

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32581 entries, 0 to 32580
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  32581 non-null  int64
#  1   person_income               32581 non-null  int64
#  2   person_home_ownership       32581 non-null  object
#  3   person_emp_length           31686 non-null  float64
#  4   loan_intent                 32581 non-null  object
#  5   loan_grade                  32581 non-null  object
#  6   loan_amnt                   32581 non-null  int64
#  7   loan_int_rate               29465 non-null  float64
#  8   loan_status                 32581 non-null  int64
#  9   loan_percent_income         32581 non-null  float64
#  10  cb_person_default_on_file   32581 non-null  object
#  11  cb_person_cred_hist_length  32581 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.0+ MB

# %%
X = df.drop('loan_status',axis=1)

# %%
Y = df['loan_status']

# %%
df.columns
# Out:
# Index(['person_age', 'person_income', 'person_home_ownership',
#        'person_emp_length', 'loan_intent', 'loan_grade', 'loan_amnt',
#        'loan_int_rate', 'loan_status', 'loan_percent_income',
#        'cb_person_default_on_file', 'cb_person_cred_hist_length'],
#       dtype='object')

# %%
# This data is for loan approval status 
# It has only 2 columns that has missing values and we have to impute them.
# In this dataset the column name loan_status is the target column
# So in this data we split the data in features and target column

# %% [markdown]
# Checking missing value and impute them by checking outlier

# %%
X.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              895
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3116
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
# person_emp_length ,loan_int_rate has the missing values

# %%
len(X)
# Out:
# 32581

# %%
missing_percentage = (df.isnull().sum() / len(X)) * 100
print(missing_percentage)
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             2.747000
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 9.563856
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %%
sns.boxplot(x='person_emp_length',data=X)
plt.show()

# %%
X['person_emp_length'].fillna(X['person_emp_length'].median(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8128\2076845757.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['person_emp_length'].fillna(X['person_emp_length'].median(),inplace=True)

# %%
sns.boxplot(x='loan_int_rate',data=X)
plt.show()

# %%
X['loan_int_rate'].fillna(X['loan_int_rate'].median(),inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8128\3379571905.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X['loan_int_rate'].fillna(X['loan_int_rate'].median(),inplace=True)

# %%
X.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %% [markdown]
# Removing duplicates from the data

# %%
X.duplicated().sum()
# Out:
# np.int64(165)

# %%
X.drop_duplicates(inplace=True)

# %%
X.duplicated().sum()
# Out:
# np.int64(0)
